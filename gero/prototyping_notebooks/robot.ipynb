# %%
from typing import List, Optional
from pydantic import BaseModel, validator
from enum import Enum, IntEnum


class ComputeModule(str, Enum):
    RPI4: "rpi4"
    IMX8M: "imx8m"
    DESKTOP: "desktop"


class Architecture(str, Enum):
    YOCTO: "yocto"
    LINUX: "linux"
    MACOS: "macos"
    WINDOWS: "windows"


class WhoMe(BaseModel):
    name: str
    # compute_module: Optional[ComputeModule]
    # architecture: Optional[Architecture]

    # class Config:
    #     """https://stackoverflow.com/questions/65209934/pydantic-enum-field-does-not-get-converted-to-string"""
    #     use_enum_values = True


class Identity(BaseModel):
    model: str
    version: float
    firmware_version: float


# class BaudRate(IntEnum):
#     BAUD_9600: 9600
#     BAUD_115200: 115200


class PortAddr(BaseModel):
    __root__: str


class SerialNumber(BaseModel):
    __root__: str


class Serial(BaseModel):
    emulated_port_addr: PortAddr
    serial_number: SerialNumber
    baud_rate: int

    @validator('baud_rate')
    def baud_rate_is_valid(cls, rate: int) -> int:
        _valid_baud_rates = [9600, 115200]
        _valid_baud_rates_str = ", ".join([str(rate) for rate in _valid_baud_rates])

        if rate not in _valid_baud_rates:
            raise ValueError(
                "value must be a valid serial baud rate: {}".format(_valid_baud_rates_str))
        return rate
    
    @validator('serial_number')
    def serial_number_must_be_valid(cls, sl: str) -> str:
        
        return sl


class Orchestrator(BaseModel):
    identity: Identity
    serial: Serial


class ChipManager(BaseModel):
    identity: Identity
    serial: Serial


class SwabManager(BaseModel):
    identity: Identity
    serial: Serial


class InputQueueManager(BaseModel):
    identity: Identity
    serial: Serial


class SolutionManager(BaseModel):
    identity: Identity
    serial: Serial
    reagent_id: str


class ResourceManagers(BaseModel):
    chip_manager: ChipManager
    swab_manager: SwabManager
    input_queue_manager: InputQueueManager
    solution_managers: List[SolutionManager]


class ChipCentrifuge(BaseModel):
    identity: Identity
    serial: Serial


class Instruments(BaseModel):
    chip_centrifuges: List[ChipCentrifuge]
    standalone_na_amplifiers: List


class Modules(BaseModel):
    orchestrator: Orchestrator
    resource_managers: ResourceManagers
    instruments: Instruments


class Offset(BaseModel):
    x: int
    y: int
    z: int


class LayoutItem(BaseModel):
    name: str
    serial_number: Optional[str] = None
    offset: Optional[Offset] = None
    rotation: Optional[int] = None


class Model(BaseModel):
    whome: WhoMe
    modules: Modules
    layout: List[LayoutItem]

# %%
from json import load
from devtools import debug

file = "../sample_config_files/Robot.json"

with open(file=file) as f:
    data = load(f)

    try:
        robot = Model(**data)
        debug(robot)
    except ValueError as e:
        print(e)
# Out:
# /var/folders/fg/1szv954j4cq_g_w5qvrpm1340000gn/T/ipykernel_18181/761122267.py:11 <cell line: 6>
#     robot: Model(
#         whome=WhoMe(
#             name='gero',
#         ),
#         modules=Modules(
#             orchestrator=Orchestrator(
#                 identity=Identity(
#                     model='min',
#                     version=1.0,
#                     firmware_version=1.0,
#                 ),
#                 serial=Serial(
#                     emulated_port_addr=PortAddr(
#                         __root__='/dev/grOrch1',
#                     ),
#                     serial_number=SerialNumber(
#                         __root__='ORCH1001',
#                     ),
#                     baud_rate=9600,
#                 ),
#             ),
#             resource_managers=ResourceManagers(
#                 chip_manager=ChipManager(
#                     identity=Identity(
#                         model='min',
#                         version=1.0,
#                         firmware_version=1.0,
#                     ),
#                     serial=Serial(
#                         emulated_port_addr=PortAddr(
#                             __root__='/dev/grChipMan1',
#                         ),
#                         serial_number=SerialNumber(
#                             __root__='CHPM1001',
#                         ),
#                         baud_rate=115200,
#                     ),
#                 ),
#                 swab_manager=SwabManager(
#                     identity=Identity(
#                         model='small',
#                         version=1.0,
#                         firmware_version=1.0,
#                     ),
#                     serial=Serial(
#                         emulated_port_addr=PortAddr(
#                             __root__='/dev/grSwabMan1',
#                         ),
#                         serial_number=SerialNumber(
#                             __root__='SWBM1001',
#                         ),
#                         baud_rate=9600,
#                     ),
#                 ),
#                 input_queue_manager=InputQueueManager(
#                     identity=Identity(
#                         model='small',
#                         version=1.0,
#                         firmware_version=1.0,
#                     ),
#                     serial=Serial(
#                         emulated_port_addr=PortAddr(
#                             __root__='/dev/grInqMan1',
#                         ),
#                         serial_number=SerialNumber(
#                             __root__='INQM1001',
#                         ),
#                         baud_rate=9600,
#                     ),
#                 ),
#                 solution_managers=[
#                     SolutionManager(
#                         identity=Identity(
#                             model='peltier-cooled',
#                             version=1.0,
#                             firmware_version=1.0,
#                         ),
#                         serial=Serial(
#                             emulated_port_addr=PortAddr(
#                                 __root__='/dev/grSolMan1',
#                             ),
#                             serial_number=SerialNumber(
#                                 __root__='SOLM1001',
#                             ),
#                             baud_rate=9600,
#                         ),
#                         reagent_id='hcl-0.1M',
#                     ),
#                 ],
#             ),
#             instruments=Instruments(
#                 chip_centrifuges=[
#                     ChipCentrifuge(
#                         identity=Identity(
#                             model='low_speed',
#                             version=1.0,
#                             firmware_version=1.0,
#                         ),
#                         serial=Serial(
#                             emulated_port_addr=PortAddr(
#                                 __root__='/dev/grCentri1',
#                             ),
#                             serial_number=SerialNumber(
#                                 __root__='CENT1001',
#                             ),
#                             baud_rate=115200,
#                         ),
#                     ),
#                     ChipCentrifuge(
#                         identity=Identity(
#                             model='low_speed',
#                             version=1.0,
#                             firmware_version=1.0,
#                         ),
#                         serial=Serial(
#                             emulated_port_addr=PortAddr(
#                                 __root__='/dev/grCentri2',
#                             ),
#                             serial_number=SerialNumber(
#                                 __root__='CENT1002',
#                             ),
#                             baud_rate=9600,
#                         ),
#                     ),
#                 ],
#                 standalone_na_amplifiers=[],
#             ),
#         ),
#         layout=[
#             LayoutItem(
#                 name='chip_centrifuges',
#                 serial_number='',
#                 offset=Offset(
#                     x=10,
#                     y=100,
#                     z=120,
#                 ),
#                 rotation=None,
#             ),
#             LayoutItem(
#                 name='chip_centrifuges',
#                 serial_number='',
#                 offset=None,
#                 rotation=None,
#             ),
#             LayoutItem(
#                 name='input_queue_manager',
#                 serial_number=None,
#                 offset=None,
#                 rotation=90,
#             ),
#         ],
#     ) (Model)
